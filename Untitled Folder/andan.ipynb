# %%
import pandas as pd

# %%
df = pd.read_csv('train3_b (1).csv')
df
# Out:
#          Country Region  Economy  Health
# 0    Switzerland      J     1.40    0.94
# 1        Iceland      J     1.30    0.95
# 2        Denmark      J     1.33    0.87
# 3         Norway      J     1.46    0.89
# 4         Canada      F     1.33    0.91
# ..           ...    ...      ...     ...
# 153       Rwanda      I     0.22    0.43
# 154        Benin      I     0.29    0.32
# 155        Syria      E     0.66    0.72
# 156      Burundi      I     0.02    0.22
# 157         Togo      I     0.21    0.28
#
# [158 rows x 4 columns]

# %%
df.groupby('Region')['Country'].nunique().sort_values(aschgending = False).plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot('Health', 'Economy', kind = 'scatter')
# Out:
# <Axes: xlabel='Health', ylabel='Economy'>

# %%
df = pd.read_csv('train1_b.csv')
df
# Out:
#       season   atemp  humidity  windspeed
# 0          1  14.395        81     0.0000
# 1          1  13.635        80     0.0000
# 2          1  13.635        80     0.0000
# 3          1  14.395        75     0.0000
# 4          1  14.395        75     0.0000
# ...      ...     ...       ...        ...
# 5417       4  17.425        53    11.0014
# 5418       4  20.455        40    11.0014
# 5419       4  17.425        53     8.9981
# 5420       4  17.425        57    11.0014
# 5421       4  17.425        53    11.0014
#
# [5422 rows x 4 columns]

# %%
df['atemp'].plot(kind = 'hist', bins = 15)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot('atemp', 'humidity', kind = 'scatter')
# Out:
# <Axes: xlabel='atemp', ylabel='humidity'>

# %%
df = pd.read_csv('train2_b.csv')
df
# Out:
#      cat  total_fat  protein  calcium
# 0      3         20       17       25
# 1      3         12       18       25
# 2      3         35       14       25
# 3      3         43       21       30
# 4      3         35       21       25
# ..   ...        ...      ...      ...
# 255    8         26       12       40
# 256    8         35       15       50
# 257    8         17        8       25
# 258    8         50       21       60
# 259    8         25       10       30
#
# [260 rows x 4 columns]

# %%
df['cat'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='cat'>

# %%
df.plot('total_fat', 'protein', kind = 'scatter')
# Out:
# <Axes: xlabel='total_fat', ylabel='protein'>

# %%
df = pd.read_csv('train3_b (1).csv')
df
# Out:
#          Country Region  Economy  Health
# 0    Switzerland      J     1.40    0.94
# 1        Iceland      J     1.30    0.95
# 2        Denmark      J     1.33    0.87
# 3         Norway      J     1.46    0.89
# 4         Canada      F     1.33    0.91
# ..           ...    ...      ...     ...
# 153       Rwanda      I     0.22    0.43
# 154        Benin      I     0.29    0.32
# 155        Syria      E     0.66    0.72
# 156      Burundi      I     0.02    0.22
# 157         Togo      I     0.21    0.28
#
# [158 rows x 4 columns]

# %%
df.groupby('Region')['Country'].nunique().sort_values().plot()
# Out:
# <Axes: xlabel='Region'>

# %%
df.plot('Health','Economy', kind = 'scatter')
# Out:
# <Axes: xlabel='Health', ylabel='Economy'>

# %%
df = pd.read_csv('train4_b.csv')
df
# Out:
#      Age  Sex  Credit amount  Duration
# 0     67    0           1169         6
# 1     22    1           5951        48
# 2     49    0           2096        12
# 3     45    0           7882        42
# 4     53    0           4870        24
# ..   ...  ...            ...       ...
# 795   22    1           2301         9
# 796   51    0           7511        18
# 797   22    1           1258        12
# 798   54    0            717        24
# 799   35    0           1549         9
#
# [800 rows x 4 columns]

# %%
df['Sex'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
df.plot('Age','Duration', kind = 'scatter')
# Out:
# <Axes: xlabel='Age', ylabel='Duration'>

# %%
df = pd.read_csv('train5_b.csv')
df
# Out:
#      Soil_Type  Sunlight_Hours  Temperature   Humidity
# 0            2        5.192294    31.719602  61.591861
# 1            3        4.033133    28.919484  52.422276
# 2            2        8.892769    23.179059  44.660539
# 3            2        8.241144    18.465886  46.433227
# 4            3        8.374043    18.128741  63.625923
# ..         ...             ...          ...        ...
# 188          3        5.652000    28.000000  70.200000
# 189          1        7.528000    30.500000  60.100000
# 190          2        4.934000    24.500000  61.700000
# 191          3        8.273000    27.900000  69.500000
# 192          1        6.732000    21.700000  56.900000
#
# [193 rows x 4 columns]

# %%
df['Humidity'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df.plot('Temperature', 'Humidity', kind = 'scatter')
# Out:
# <Axes: xlabel='Temperature', ylabel='Humidity'>

# %%
df[['Soil_Type', 'Temperature']].corr()
# Out:
#              Soil_Type  Temperature
# Soil_Type     1.000000    -0.013128
# Temperature  -0.013128     1.000000

# %%
df = pd.read_csv('train4_b.csv')
df
# Out:
#      Age  Sex  Credit amount  Duration
# 0     67    0           1169         6
# 1     22    1           5951        48
# 2     49    0           2096        12
# 3     45    0           7882        42
# 4     53    0           4870        24
# ..   ...  ...            ...       ...
# 795   22    1           2301         9
# 796   51    0           7511        18
# 797   22    1           1258        12
# 798   54    0            717        24
# 799   35    0           1549         9
#
# [800 rows x 4 columns]

# %%
df[['Credit amount', 'Duration']].corr()
# Out:
#                Credit amount  Duration
# Credit amount       1.000000  0.627333
# Duration            0.627333  1.000000

# %%
df = pd.read_csv('train3_b (1).csv')
df
# Out:
#          Country Region  Economy  Health
# 0    Switzerland      J     1.40    0.94
# 1        Iceland      J     1.30    0.95
# 2        Denmark      J     1.33    0.87
# 3         Norway      J     1.46    0.89
# 4         Canada      F     1.33    0.91
# ..           ...    ...      ...     ...
# 153       Rwanda      I     0.22    0.43
# 154        Benin      I     0.29    0.32
# 155        Syria      E     0.66    0.72
# 156      Burundi      I     0.02    0.22
# 157         Togo      I     0.21    0.28
#
# [158 rows x 4 columns]

# %%
df[['Economy', 'Health']].corr()
# Out:
#           Economy    Health
# Economy  1.000000  0.816771
# Health   0.816771  1.000000

# %%
df = pd.read_csv('train2_b.csv')
df
# Out:
#      cat  total_fat  protein  calcium
# 0      3         20       17       25
# 1      3         12       18       25
# 2      3         35       14       25
# 3      3         43       21       30
# 4      3         35       21       25
# ..   ...        ...      ...      ...
# 255    8         26       12       40
# 256    8         35       15       50
# 257    8         17        8       25
# 258    8         50       21       60
# 259    8         25       10       30
#
# [260 rows x 4 columns]

# %%
df[['calcium', 'protein']].corr()
# Out:
#           calcium   protein
# calcium  1.000000  0.327971
# protein  0.327971  1.000000

# %%
df = pd.read_csv('train1_b.csv')
df
# Out:
#       season   atemp  humidity  windspeed
# 0          1  14.395        81     0.0000
# 1          1  13.635        80     0.0000
# 2          1  13.635        80     0.0000
# 3          1  14.395        75     0.0000
# 4          1  14.395        75     0.0000
# ...      ...     ...       ...        ...
# 5417       4  17.425        53    11.0014
# 5418       4  20.455        40    11.0014
# 5419       4  17.425        53     8.9981
# 5420       4  17.425        57    11.0014
# 5421       4  17.425        53    11.0014
#
# [5422 rows x 4 columns]

# %%
df[['atemp', 'windspeed']].corr()
# Out:
#               atemp  windspeed
# atemp      1.000000  -0.039005
# windspeed -0.039005   1.000000

# %%
df['humidity'].quantile(0.25)
# Out:
# 49.0

# %%
df = pd.read_csv('train1_C.csv')
df
# Out:
#                    Car Name  Year     Region  FuelType  Mileage  Price  Owners
# 0              Ford Transit  2002      Goris    Diesel   215000  12000       4
# 1                Ford Focus  2017     Ijevan  Gasoline    72000  11500       5
# 2               Opel Vectra  1998    Armavir  Gasoline   466000   4000       5
# 3                   Mazda 6  2020   Nor Nork  Gasoline   100000  22000       3
# 4               Opel Vectra  1998    Armavir  Gasoline   318000   3500       6
# ...                     ...   ...        ...       ...      ...    ...     ...
# 7990  VAZ (Lada) 2121 (4x4)  2013    Armavir  Gasoline   150000  35000       5
# 7991         Toyota 4Runner  2018   Nor Nork  Gasoline    94000   5600       4
# 7992   Opel Astra hatchback  2001   Ajapnyak  Gasoline   151000   9800       3
# 7993           Toyota Camry  2009  Shengavit  Gasoline   300000   4500       6
# 7994  Mercedes-Benz C-Class  1997  Nor Geghi  Gasoline   200000   3200       6
#
# [7995 rows x 7 columns]

# %%
df[(df['FuelType'] == 'Gasoline')&(df['Region'] == 'Armavir')].sort_values('Year').head(1)['Car Name'].values[0]
# Out:
# 'Mercedes-Benz W124'

# %%
df = pd.read_csv('train2_C.csv')
df
# Out:
#           price  bedrooms  sqft_living  sqft_lot  waterfront  grade  yr_built  \
# 0      221900.0         3         1180      5650           0      7      1955
# 1      538000.0         3         2570      7242           0      7      1951
# 2      180000.0         2          770     10000           0      6      1933
# 3      604000.0         4         1960      5000           0      7      1965
# 4      510000.0         3         1680      8080           0      8      1987
# ...         ...       ...          ...       ...         ...    ...       ...
# 21608  360000.0         3         1530      1131           0      8      2009
# 21609  400000.0         4         2310      5813           0      8      2014
# 21610  402101.0         2         1020      1350           0      7      2009
# 21611  400000.0         3         1600      2388           0      8      2004
# 21612  325000.0         2         1020      1076           0      7      2008
#
#        yr_renovated
# ...

# %%
df[df['bedrooms'] == 1].sort_values('sqft_lot').head(1)['yr_built'].values[0]
# Out:
# 2014

# %%
df = pd.read_csv('train3_C.csv')
df
# Out:
#             data  public_transport_usage  pedestrian_count  temperature  \
# 0     2023-01-01              288.333333        863.833333    12.704031
# 1     2023-01-02              232.541667        830.333333    11.343628
# 2     2023-01-03              267.458333        891.125000    13.902640
# 3     2023-01-04              257.791667        876.625000    17.733302
# 4     2023-01-05              281.083333       1036.291667    13.445025
# ...          ...                     ...               ...          ...
# 3558  2137-01-25              258.666667        940.041667     8.727096
# 3559  2137-01-26              247.083333        999.458333    12.890842
# 3560  2137-01-27              311.958333       1037.666667    12.277605
# 3561  2137-01-28              278.166667       1030.375000    13.822088
# 3562  2137-01-29              277.812500        768.000000    15.765083
#
#        humidity  public_transport_delay weather_conditions day_of_week  \
# ...

# %%
df[(df['day_of_week'] == 'Friday') | (df['day_of_week'] == 'Saturday')].sort_values('humidity', ascending = False).head(1)['public_transport_usage'].values[0]
# Out:
# 306.25

# %%
df = pd.read_csv('train3_C.csv')
df
# Out:
#             data  public_transport_usage  pedestrian_count  temperature  \
# 0     2023-01-01              288.333333        863.833333    12.704031
# 1     2023-01-02              232.541667        830.333333    11.343628
# 2     2023-01-03              267.458333        891.125000    13.902640
# 3     2023-01-04              257.791667        876.625000    17.733302
# 4     2023-01-05              281.083333       1036.291667    13.445025
# ...          ...                     ...               ...          ...
# 3558  2137-01-25              258.666667        940.041667     8.727096
# 3559  2137-01-26              247.083333        999.458333    12.890842
# 3560  2137-01-27              311.958333       1037.666667    12.277605
# 3561  2137-01-28              278.166667       1030.375000    13.822088
# 3562  2137-01-29              277.812500        768.000000    15.765083
#
#        humidity  public_transport_delay weather_conditions day_of_week  \
# ...

# %%
df.groupby(['day_of_week'])['public_transport_delay'].var().sort_values()
# Out:
# day_of_week
# Saturday     2.871412
# Friday       2.892978
# Thursday     2.914371
# Tuesday      3.024859
# Monday       3.068628
# Sunday       3.229770
# Wednesday    3.393490
# Name: public_transport_delay, dtype: float64

# %%
df = pd.read_csv('train1_C.csv')
df
# Out:
#                    Car Name  Year     Region  FuelType  Mileage  Price  Owners
# 0              Ford Transit  2002      Goris    Diesel   215000  12000       4
# 1                Ford Focus  2017     Ijevan  Gasoline    72000  11500       5
# 2               Opel Vectra  1998    Armavir  Gasoline   466000   4000       5
# 3                   Mazda 6  2020   Nor Nork  Gasoline   100000  22000       3
# 4               Opel Vectra  1998    Armavir  Gasoline   318000   3500       6
# ...                     ...   ...        ...       ...      ...    ...     ...
# 7990  VAZ (Lada) 2121 (4x4)  2013    Armavir  Gasoline   150000  35000       5
# 7991         Toyota 4Runner  2018   Nor Nork  Gasoline    94000   5600       4
# 7992   Opel Astra hatchback  2001   Ajapnyak  Gasoline   151000   9800       3
# 7993           Toyota Camry  2009  Shengavit  Gasoline   300000   4500       6
# 7994  Mercedes-Benz C-Class  1997  Nor Geghi  Gasoline   200000   3200       6
#
# [7995 rows x 7 columns]

# %%
grouped = df.groupby(['Region'])['Price'].describe()[['25%', '75%']]

# %%
grouped['IQR'] = grouped['75%'] - grouped['25%']

# %%
count = len(grouped[grouped['IQR'] == 0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'IQR'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
 df = pd.read_csv('train2_C.csv')
df
# Out:
#           price  bedrooms  sqft_living  sqft_lot  waterfront  grade  yr_built  \
# 0      221900.0         3         1180      5650           0      7      1955
# 1      538000.0         3         2570      7242           0      7      1951
# 2      180000.0         2          770     10000           0      6      1933
# 3      604000.0         4         1960      5000           0      7      1965
# 4      510000.0         3         1680      8080           0      8      1987
# ...         ...       ...          ...       ...         ...    ...       ...
# 21608  360000.0         3         1530      1131           0      8      2009
# 21609  400000.0         4         2310      5813           0      8      2014
# 21610  402101.0         2         1020      1350           0      7      2009
# 21611  400000.0         3         1600      2388           0      8      2004
# 21612  325000.0         2         1020      1076           0      7      2008
#
#        yr_renovated
# ...

# %%
pivot_table = df.groupby('bedrooms')[['sqft_living', 'sqft_lot']].mean()

# %%
df['living_lot_ratio'] = df['sqft_living'] / df['sqft_lot']

# Группировка и расчет средних значений
pivot_table = df.groupby('bedrooms')[['sqft_living', 'sqft_lot']].mean()

# Находим максимальное значение доли жилой площади
max_ratio = df['living_lot_ratio'].max()

# Находим количество спален с максимальной долей
bedrooms_with_max_ratio = df[df['living_lot_ratio'] == max_ratio]['bedrooms'].iloc[0]

print(pivot_table)
print(f"\nКоличество спален в домах с максимальной долей жилой площади: {bedrooms_with_max_ratio:.2f}")
# Out:
#           sqft_living      sqft_lot
# bedrooms
# 0         1707.846154  24141.307692
# 1          884.613065  16285.673367
# 2         1239.752899  12096.726087
# 3         1805.837235  14414.790208
# 4         2554.649666  16720.793374
# 5         3047.545284  16769.022486
# 6         3284.341912  18586.930147
# 7         3974.210526  20840.552632
# 8         3800.000000   8971.615385
# 9         3775.000000   5480.000000
# 10        3706.666667   8859.666667
# 11        3000.000000   4960.000000
# 33        1620.000000   6000.000000
#
# Количество спален в домах с максимальной долей жилой площади: 4.00

# %%
df['living_lot_ratio'] = df['sqft_living'] / df['sqft_lot']

# %%
pivot_table = df.groupby('bedrooms')[['sqft_living', 'sqft_lot']].mean()

# %%
max_ratio = df['living_lot_ratio'].max()

# %%
bedrooms_with_max_ratio = df[df['living_lot_ratio'] == max_ratio]['bedrooms'].iloc[0]
pivot_table
# Out:
#           sqft_living      sqft_lot
# bedrooms
# 0         1707.846154  24141.307692
# 1          884.613065  16285.673367
# 2         1239.752899  12096.726087
# 3         1805.837235  14414.790208
# 4         2554.649666  16720.793374
# 5         3047.545284  16769.022486
# 6         3284.341912  18586.930147
# 7         3974.210526  20840.552632
# 8         3800.000000   8971.615385
# 9         3775.000000   5480.000000
# 10        3706.666667   8859.666667
# 11        3000.000000   4960.000000
# 33        1620.000000   6000.000000

# %%
df = pd.read_csv('train3_C.csv')
df
# Out:
#             data  public_transport_usage  pedestrian_count  temperature  \
# 0     2023-01-01              288.333333        863.833333    12.704031
# 1     2023-01-02              232.541667        830.333333    11.343628
# 2     2023-01-03              267.458333        891.125000    13.902640
# 3     2023-01-04              257.791667        876.625000    17.733302
# 4     2023-01-05              281.083333       1036.291667    13.445025
# ...          ...                     ...               ...          ...
# 3558  2137-01-25              258.666667        940.041667     8.727096
# 3559  2137-01-26              247.083333        999.458333    12.890842
# 3560  2137-01-27              311.958333       1037.666667    12.277605
# 3561  2137-01-28              278.166667       1030.375000    13.822088
# 3562  2137-01-29              277.812500        768.000000    15.765083
#
#        humidity  public_transport_delay weather_conditions day_of_week  \
# ...

# %%
df['coded'] = df['weather_conditions'].apply()

# %%
mean = df['temperature'].mean()

# %%
std = df['temperature'].std()

# %%
df[(df['temperature'] >= mean - 0.5 * std) & (df['temperature'] <= mean + 0.5 * std)]
# Out:
#             data  public_transport_usage  pedestrian_count  temperature  \
# 0     2023-01-01              288.333333        863.833333    12.704031
# 1     2023-01-02              232.541667        830.333333    11.343628
# 4     2023-01-05              281.083333       1036.291667    13.445025
# 6     2023-01-07              306.375000       1087.166667    11.372241
# 11    2023-01-12              241.375000       1212.958333    11.389462
# ...          ...                     ...               ...          ...
# 3550  2137-01-17              266.583333       1079.708333    11.241523
# 3553  2137-01-20              243.875000        868.625000    11.562002
# 3555  2137-01-22              272.291667       1066.000000    13.386127
# 3559  2137-01-26              247.083333        999.458333    12.890842
# 3560  2137-01-27              311.958333       1037.666667    12.277605
#
#        humidity  public_transport_delay weather_conditions day_of_week  \
# ...

# %%
df = pd.read_csv('train2_C.csv')
df
# Out:
#           price  bedrooms  sqft_living  sqft_lot  waterfront  grade  yr_built  \
# 0      221900.0         3         1180      5650           0      7      1955
# 1      538000.0         3         2570      7242           0      7      1951
# 2      180000.0         2          770     10000           0      6      1933
# 3      604000.0         4         1960      5000           0      7      1965
# 4      510000.0         3         1680      8080           0      8      1987
# ...         ...       ...          ...       ...         ...    ...       ...
# 21608  360000.0         3         1530      1131           0      8      2009
# 21609  400000.0         4         2310      5813           0      8      2014
# 21610  402101.0         2         1020      1350           0      7      2009
# 21611  400000.0         3         1600      2388           0      8      2004
# 21612  325000.0         2         1020      1076           0      7      2008
#
#        yr_renovated
# ...

# %%
mean = df['price'].mean()

# %%
std = df['price'].std()

# %%
outliers = df[(df['price'] >= mean - 1 * std )& (df['price'] <= mean + 1 * std )]

# %%
outliers = df[(df['price'] <= mean - 1 * std) | (df['price'] >= mean + 1 * std)]
outliers
# Out:
#            price  bedrooms  sqft_living  sqft_lot  waterfront  grade  \
# 5      1225000.0         4         5420    101930           0     11
# 21     2000000.0         3         3050     44867           0      9
# 26      937000.0         3         2450      2691           0      8
# 49     1350000.0         3         2753     65005           1      9
# 54      920000.0         5         2730      6000           0      8
# ...          ...       ...          ...       ...         ...    ...
# 21590  1222500.0         4         4910      9444           0     11
# 21593  1088000.0         5         4170      8142           0     10
# 21597  1575000.0         4         3410     10125           0     10
# 21600  1537000.0         5         4470      8088           0     11
# 21606  1007500.0         4         3510      7200           0      9
#
#        yr_built  yr_renovated
# 5          2001             0
# 21         1968             0
# 26         1915             0
# ...

# %%
df = pd.read_csv('train1_C.csv')
df
# Out:
#                    Car Name  Year     Region  FuelType  Mileage  Price  Owners
# 0              Ford Transit  2002      Goris    Diesel   215000  12000       4
# 1                Ford Focus  2017     Ijevan  Gasoline    72000  11500       5
# 2               Opel Vectra  1998    Armavir  Gasoline   466000   4000       5
# 3                   Mazda 6  2020   Nor Nork  Gasoline   100000  22000       3
# 4               Opel Vectra  1998    Armavir  Gasoline   318000   3500       6
# ...                     ...   ...        ...       ...      ...    ...     ...
# 7990  VAZ (Lada) 2121 (4x4)  2013    Armavir  Gasoline   150000  35000       5
# 7991         Toyota 4Runner  2018   Nor Nork  Gasoline    94000   5600       4
# 7992   Opel Astra hatchback  2001   Ajapnyak  Gasoline   151000   9800       3
# 7993           Toyota Camry  2009  Shengavit  Gasoline   300000   4500       6
# 7994  Mercedes-Benz C-Class  1997  Nor Geghi  Gasoline   200000   3200       6
#
# [7995 rows x 7 columns]

# %%
mean = df['Price'].mean()
std = df['Price'].std()

# %%
mean = df['Price'].mean()
std = df['Price'].std()
outliers = df[(df['Price'] <= mean - 1.5 * std) | (df['Price'] >= mean + 1.5 * std)]
outliers
# Out:
#                        Car Name  Year            Region  FuelType  Mileage  \
# 42                Infiniti QX80  2021         Shengavit  Gasoline    94000
# 49    Mercedes-Benz G-Class AMG  2015           Kentron  Gasoline    74000
# 50          Toyota Land Cruiser  2020           Kentron  Gasoline    30000
# 185     Mercedes-Benz GLE Coupe  2019  Malatia-Sebastia  Gasoline    29000
# 217                    Lexus RX  2021              Avan  Gasoline    20000
# ...                         ...   ...               ...       ...      ...
# 7884               BMW 5 Series  2017           Abovian  Gasoline    80000
# 7915       Mitsubishi Pajero IO  1998           Erebuni  Gasoline   300000
# 7953       Opel Astra hatchback  1999         Shengavit  Gasoline   170000
# 7957  VAZ (Lada) 2114 hatchback  2010             Goris  Gasoline   209000
# 7958       Rolls-Royce Cullinan  2020         Davtashen  Gasoline    19150
#
#        Price  Owners
# 42     45000       6
# 49    115000       5
# ...

# %%
outliers = df[(df['Price'] < mean - 1.5 * std) | (df['Price'] > mean + 1.5 * std)]

# %%
df = pd.read_csv('train4_C.csv')
df
# Out:
#              song_name                                       album_name  \
# 0           Tom Sawyer  Moving Pictures (40th Anniversary Super Deluxe)
# 1        Red Barchetta  Moving Pictures (40th Anniversary Super Deluxe)
# 2                  YYZ  Moving Pictures (40th Anniversary Super Deluxe)
# 3            Limelight  Moving Pictures (40th Anniversary Super Deluxe)
# 4       The Camera Eye  Moving Pictures (40th Anniversary Super Deluxe)
# ..                 ...                                              ...
# 555         Here Again                                             Rush
# 556  What You're Doing                                             Rush
# 557        In The Mood                                             Rush
# 558   Before And After                                             Rush
# 559        Working Man                                             Rush
#
#      track_number  popularity  danceability  energy  loudness  mode  \
# ...

# %%
mean = df['tempo'].mean()
std = df['tempo'].std()
lala = df[(df['tempo'] <= mean - 2.5 * std) | (df['tempo'] >= mean + 2.5 * std)]
lala
# Out:
#                                              song_name  \
# 62                                            Madrigal
# 85                                A Passage To Bangkok
# 233  A Passage to Bangkok - Snakes & Arrows Live Ve...
# 278                     Working Man - R30 Live Version
# 318                             Working Man - Rio Live
# 345                            2112 (Discovery) - Live
# 346                         2112 (Presentation) - Live
# 368                                      Anthem - Live
# 458                                     The Analog Kid
# 525                               A Passage To Bangkok
#
#                                             album_name  track_number  \
# 62   A Farewell To Kings (40th Anniversary Deluxe E...             5
# 85                               2112 (40 Anniversary)             2
# 233                               Snakes & Arrows Live            26
# 278                                                R30            19
# ...

# %%
df = pd.read_csv('train3_C.csv')
df
# Out:
#             data  public_transport_usage  pedestrian_count  temperature  \
# 0     2023-01-01              288.333333        863.833333    12.704031
# 1     2023-01-02              232.541667        830.333333    11.343628
# 2     2023-01-03              267.458333        891.125000    13.902640
# 3     2023-01-04              257.791667        876.625000    17.733302
# 4     2023-01-05              281.083333       1036.291667    13.445025
# ...          ...                     ...               ...          ...
# 3558  2137-01-25              258.666667        940.041667     8.727096
# 3559  2137-01-26              247.083333        999.458333    12.890842
# 3560  2137-01-27              311.958333       1037.666667    12.277605
# 3561  2137-01-28              278.166667       1030.375000    13.822088
# 3562  2137-01-29              277.812500        768.000000    15.765083
#
#        humidity  public_transport_delay weather_conditions day_of_week  \
# ...

# %%
df.corr(numeric_only = True)['humidity']
# Out:
# public_transport_usage   -0.000398
# pedestrian_count         -0.023459
# temperature              -0.005451
# humidity                  1.000000
# public_transport_delay   -0.029741
# pedestrian_incidents      0.017286
# Name: humidity, dtype: float64

# %%
df = pd.read_csv('train5_C.csv')
df
# Out:
#                                                 Resort          Country  \
# 0                                Alpendorf (Ski amedé)          Austria
# 1    Soldeu-Pas de la Casa/​Grau Roig/​El Tarter/​C...          Andorra
# 2                                Oberau (Wildschönau)          Austria
# 3                                       Dachstein West          Austria
# 4                                          Rosa Khutor  Southern Russia
# ..                                                 ...              ...
# 371                          Montgenèvre (Via Lattea)           France
# 372                          Sauze d’Oulx (Via Lattea)            Italy
# 373             Gressoney - La-Trinite (Monterosa Ski)            Italy
# 374                          Champoluc (Monterosa Ski)            Italy
# 375                                         Zauchensee          Austria
#
#      HighestPoint  LowestPoint  DayPassPriceAdult  TotalSlope NightSki  \
# ...

# %%
df.corr(numeric_only = True)['LiftCapacity']
# Out:
# HighestPoint         0.389346
# LowestPoint          0.054446
# DayPassPriceAdult    0.462764
# TotalSlope           0.936038
# TotalLifts           0.983835
# LiftCapacity         1.000000
# Name: LiftCapacity, dtype: float64

# %%
df = pd.read_csv('train4_C.csv')
df
# Out:
#              song_name                                       album_name  \
# 0           Tom Sawyer  Moving Pictures (40th Anniversary Super Deluxe)
# 1        Red Barchetta  Moving Pictures (40th Anniversary Super Deluxe)
# 2                  YYZ  Moving Pictures (40th Anniversary Super Deluxe)
# 3            Limelight  Moving Pictures (40th Anniversary Super Deluxe)
# 4       The Camera Eye  Moving Pictures (40th Anniversary Super Deluxe)
# ..                 ...                                              ...
# 555         Here Again                                             Rush
# 556  What You're Doing                                             Rush
# 557        In The Mood                                             Rush
# 558   Before And After                                             Rush
# 559        Working Man                                             Rush
#
#      track_number  popularity  danceability  energy  loudness  mode  \
# ...

# %%
df.corr(numeric_only = True)['tempo']
# Out:
# track_number       -0.029857
# popularity          0.060082
# danceability       -0.173643
# energy              0.114065
# loudness           -0.007619
# mode                0.087254
# instrumentalness    0.081264
# valence            -0.006837
# tempo               1.000000
# Name: tempo, dtype: float64

# %%
df = pd.read_csv('train2_C.csv')
df
# Out:
#           price  bedrooms  sqft_living  sqft_lot  waterfront  grade  yr_built  \
# 0      221900.0         3         1180      5650           0      7      1955
# 1      538000.0         3         2570      7242           0      7      1951
# 2      180000.0         2          770     10000           0      6      1933
# 3      604000.0         4         1960      5000           0      7      1965
# 4      510000.0         3         1680      8080           0      8      1987
# ...         ...       ...          ...       ...         ...    ...       ...
# 21608  360000.0         3         1530      1131           0      8      2009
# 21609  400000.0         4         2310      5813           0      8      2014
# 21610  402101.0         2         1020      1350           0      7      2009
# 21611  400000.0         3         1600      2388           0      8      2004
# 21612  325000.0         2         1020      1076           0      7      2008
#
#        yr_renovated
# ...

# %%
df.corr(numeric_only = True)['grade']
# Out:
# price           0.667434
# bedrooms        0.356967
# sqft_living     0.762704
# sqft_lot        0.113621
# waterfront      0.082775
# grade           1.000000
# yr_built        0.446963
# yr_renovated    0.014414
# Name: grade, dtype: float64

# %%
df = pd.read_csv('train3_C.csv')
df
# Out:
#             data  public_transport_usage  pedestrian_count  temperature  \
# 0     2023-01-01              288.333333        863.833333    12.704031
# 1     2023-01-02              232.541667        830.333333    11.343628
# 2     2023-01-03              267.458333        891.125000    13.902640
# 3     2023-01-04              257.791667        876.625000    17.733302
# 4     2023-01-05              281.083333       1036.291667    13.445025
# ...          ...                     ...               ...          ...
# 3558  2137-01-25              258.666667        940.041667     8.727096
# 3559  2137-01-26              247.083333        999.458333    12.890842
# 3560  2137-01-27              311.958333       1037.666667    12.277605
# 3561  2137-01-28              278.166667       1030.375000    13.822088
# 3562  2137-01-29              277.812500        768.000000    15.765083
#
#        humidity  public_transport_delay weather_conditions day_of_week  \
# ...

# %%
import statsmodels.api as sm

# %%
X = sm.add_constant(df[['pedestrian_incidents']])
Y = df['temperature']
model = sm.OLS(Y, X).fit()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[176], line 1
# ----> 1 X = sm.add_constant(df[['pedestrian_incidents']])
#       2 Y = df['temperature']
#       3 model = sm.OLS(Y, X).fit()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
# ...

# %%
model.params
# Out:
# const      18109.868446
# Mileage       -0.017451
# dtype: float64

# %%
df = pd.read_csv('train1_C.csv')
df
# Out:
#                    Car Name  Year     Region  FuelType  Mileage  Price  Owners
# 0              Ford Transit  2002      Goris    Diesel   215000  12000       4
# 1                Ford Focus  2017     Ijevan  Gasoline    72000  11500       5
# 2               Opel Vectra  1998    Armavir  Gasoline   466000   4000       5
# 3                   Mazda 6  2020   Nor Nork  Gasoline   100000  22000       3
# 4               Opel Vectra  1998    Armavir  Gasoline   318000   3500       6
# ...                     ...   ...        ...       ...      ...    ...     ...
# 7990  VAZ (Lada) 2121 (4x4)  2013    Armavir  Gasoline   150000  35000       5
# 7991         Toyota 4Runner  2018   Nor Nork  Gasoline    94000   5600       4
# 7992   Opel Astra hatchback  2001   Ajapnyak  Gasoline   151000   9800       3
# 7993           Toyota Camry  2009  Shengavit  Gasoline   300000   4500       6
# 7994  Mercedes-Benz C-Class  1997  Nor Geghi  Gasoline   200000   3200       6
#
# [7995 rows x 7 columns]

# %%
import statsmodels.api as sm

# %%
X = sm.add_constant(df[['Mileage']])
Y = df['Price']
model = sm.OLS(Y, X).fit()

# %%
model.params
# Out:
# const      18109.868446
# Mileage       -0.017451
# dtype: float64

# %%
b = -0.017451 * 18109.868446
b
# Out:
# -316.035314251146

# %%
df = pd.read_csv('train2_C.csv')
df
# Out:
#           price  bedrooms  sqft_living  sqft_lot  waterfront  grade  yr_built  \
# 0      221900.0         3         1180      5650           0      7      1955
# 1      538000.0         3         2570      7242           0      7      1951
# 2      180000.0         2          770     10000           0      6      1933
# 3      604000.0         4         1960      5000           0      7      1965
# 4      510000.0         3         1680      8080           0      8      1987
# ...         ...       ...          ...       ...         ...    ...       ...
# 21608  360000.0         3         1530      1131           0      8      2009
# 21609  400000.0         4         2310      5813           0      8      2014
# 21610  402101.0         2         1020      1350           0      7      2009
# 21611  400000.0         3         1600      2388           0      8      2004
# 21612  325000.0         2         1020      1076           0      7      2008
#
#        yr_renovated
# ...

# %%
import statsmodels.api as sm
X = sm.add_constant(df[['sqft_living']])
Y = df['price']
model = sm.OLS(Y, X).fit()

# %%
model.params
# Out:
# const         -43580.743094
# sqft_living      280.623568
# dtype: float64

# %%
df = pd.read_csv('train3_C.csv')
df
# Out:
#             data  public_transport_usage  pedestrian_count  temperature  \
# 0     2023-01-01              288.333333        863.833333    12.704031
# 1     2023-01-02              232.541667        830.333333    11.343628
# 2     2023-01-03              267.458333        891.125000    13.902640
# 3     2023-01-04              257.791667        876.625000    17.733302
# 4     2023-01-05              281.083333       1036.291667    13.445025
# ...          ...                     ...               ...          ...
# 3558  2137-01-25              258.666667        940.041667     8.727096
# 3559  2137-01-26              247.083333        999.458333    12.890842
# 3560  2137-01-27              311.958333       1037.666667    12.277605
# 3561  2137-01-28              278.166667       1030.375000    13.822088
# 3562  2137-01-29              277.812500        768.000000    15.765083
#
#        humidity  public_transport_delay weather_conditions day_of_week  \
# ...

# %%
import statsmodels.api as sm
X = sm.add_constant(df[['temperature']])
Y = df['pedestrian_incidents']
model = sm.OLS(Y, X).fit()

# %%
model.params
# Out:
# const          48.382144
# temperature    -0.025883
# dtype: float64

# %%
pred = model.predict(X)

# %%
pred
# Out:
# 0       48.053321
# 1       48.088533
# 2       48.022297
# 3       47.923147
# 4       48.034142
#           ...
# 3558    48.156257
# 3559    48.048486
# 3560    48.064358
# 3561    48.024382
# 3562    47.974091
# Length: 3563, dtype: float64

# %%
sum(abs(Y-pred)/len(Y))
# Out:
# 5.53126858554768

# %%
(50 + 50 - 50 + 100)/4
# Out:
# 37.5

# %%
200 + 40*20
# Out:
# 1000

# %%
0.75*3
# Out:
# 2.25

# %%
2.25 - 0.75
# Out:
# 1.5

# %%
df = pd.read_csv('train2_b.csv')
df
# Out:
#      cat  total_fat  protein  calcium
# 0      3         20       17       25
# 1      3         12       18       25
# 2      3         35       14       25
# 3      3         43       21       30
# 4      3         35       21       25
# ..   ...        ...      ...      ...
# 255    8         26       12       40
# 256    8         35       15       50
# 257    8         17        8       25
# 258    8         50       21       60
# 259    8         25       10       30
#
# [260 rows x 4 columns]

# %%
n = df['calcium'].quantile(0.5)

# %%
df = pd.read_csv('train3_b (1).csv')
df
# Out:
#          Country Region  Economy  Health
# 0    Switzerland      J     1.40    0.94
# 1        Iceland      J     1.30    0.95
# 2        Denmark      J     1.33    0.87
# 3         Norway      J     1.46    0.89
# 4         Canada      F     1.33    0.91
# ..           ...    ...      ...     ...
# 153       Rwanda      I     0.22    0.43
# 154        Benin      I     0.29    0.32
# 155        Syria      E     0.66    0.72
# 156      Burundi      I     0.02    0.22
# 157         Togo      I     0.21    0.28
#
# [158 rows x 4 columns]

# %%
df['Region'].nunique()
# Out:
# 10

# %%
df = pd.read_csv('train4_b.csv')
df
# Out:
#      Age  Sex  Credit amount  Duration
# 0     67    0           1169         6
# 1     22    1           5951        48
# 2     49    0           2096        12
# 3     45    0           7882        42
# 4     53    0           4870        24
# ..   ...  ...            ...       ...
# 795   22    1           2301         9
# 796   51    0           7511        18
# 797   22    1           1258        12
# 798   54    0            717        24
# 799   35    0           1549         9
#
# [800 rows x 4 columns]

# %%
counter = df['Sex'].sum()

# %%
final = len(df)

# %%
pupuup = counter/ final
pupuup
# Out:
# 0.31875

# %%
df = pd.read_csv('train2_C.csv')
df
# Out:
#           price  bedrooms  sqft_living  sqft_lot  waterfront  grade  yr_built  \
# 0      221900.0         3         1180      5650           0      7      1955
# 1      538000.0         3         2570      7242           0      7      1951
# 2      180000.0         2          770     10000           0      6      1933
# 3      604000.0         4         1960      5000           0      7      1965
# 4      510000.0         3         1680      8080           0      8      1987
# ...         ...       ...          ...       ...         ...    ...       ...
# 21608  360000.0         3         1530      1131           0      8      2009
# 21609  400000.0         4         2310      5813           0      8      2014
# 21610  402101.0         2         1020      1350           0      7      2009
# 21611  400000.0         3         1600      2388           0      8      2004
# 21612  325000.0         2         1020      1076           0      7      2008
#
#        yr_renovated
# ...

# %%
df[df['bedrooms'] == 1].sort_values('sqft_lot').head(1)['yr_built'].values[0]
# Out:
# 2014

# %%
df.groupby('bedrooms')(['sqft_living', 'sqft_lot']).mean()
# Out:
#           sqft_living      sqft_lot
# bedrooms
# 0         1707.846154  24141.307692
# 1          884.613065  16285.673367
# 2         1239.752899  12096.726087
# 3         1805.837235  14414.790208
# 4         2554.649666  16720.793374
# 5         3047.545284  16769.022486
# 6         3284.341912  18586.930147
# 7         3974.210526  20840.552632
# 8         3800.000000   8971.615385
# 9         3775.000000   5480.000000
# 10        3706.666667   8859.666667
# 11        3000.000000   4960.000000
# 33        1620.000000   6000.000000

# %%
df['ratio'] = df['sqft_living'] / df['sqft_lot']

# %%
df.groupby('bedrooms')[['sqft_living', 'sqft_lot']].mean()
# Out:
#           sqft_living      sqft_lot
# bedrooms
# 0         1707.846154  24141.307692
# 1          884.613065  16285.673367
# 2         1239.752899  12096.726087
# 3         1805.837235  14414.790208
# 4         2554.649666  16720.793374
# 5         3047.545284  16769.022486
# 6         3284.341912  18586.930147
# 7         3974.210526  20840.552632
# 8         3800.000000   8971.615385
# 9         3775.000000   5480.000000
# 10        3706.666667   8859.666667
# 11        3000.000000   4960.000000
# 33        1620.000000   6000.000000

# %%
max_ratio_row = df.loc[df['ratio'].idxmax()]
# Out:
# price           700000.000000
# bedrooms             4.000000
# sqft_living       2420.000000
# sqft_lot           520.000000
# waterfront           0.000000
# grade                7.000000
# yr_built          1900.000000
# yr_renovated         0.000000
# ratio                4.653846
# Name: 15743, dtype: float64

# %%
max_ratio_row['bedrooms']
# Out:
# 4.0

# %%
# Создаем столбец с долей жилой площади
df['ratio'] = df['sqft_living'] / df['sqft_lot']

# Строим сводную таблицу
pivot_table = df.groupby('bedrooms')[['sqft_living', 'sqft_lot']].mean()
print("Сводная таблица:\n", pivot_table)

# Находим дом с максимальной долей жилой площади
max_ratio_row = df.loc[df['ratio'].idxmax()]

# Выводим количество спален в этом доме
print(f"\nКоличество спален в доме с максимальной долей жилой площади: {max_ratio_row['bedrooms']:.2f}")
# Out:
# Сводная таблица:
#            sqft_living      sqft_lot
# bedrooms
# 0         1707.846154  24141.307692
# 1          884.613065  16285.673367
# 2         1239.752899  12096.726087
# 3         1805.837235  14414.790208
# 4         2554.649666  16720.793374
# 5         3047.545284  16769.022486
# 6         3284.341912  18586.930147
# 7         3974.210526  20840.552632
# 8         3800.000000   8971.615385
# 9         3775.000000   5480.000000
# 10        3706.666667   8859.666667
# 11        3000.000000   4960.000000
# 33        1620.000000   6000.000000
#
# Количество спален в доме с максимальной долей жилой площади: 4.00

# %%
import statistics
def func(x):
    if x == 0:
        return 1
    if x >= 2001:
        return 21
    else:
        return 20
df['coded'] = df['yr_renovated'].apply(func)
statistics.stdev(df['coded'])
# Out:
# 3.9182926965193348

# %%
mean = df['price'].mean()
std = df['price'].std()
n = df[(df['price'] <= mean - 1*std) | (df['price'] >= mean + 1*std)]
n
# Out:
#            price  bedrooms  sqft_living  sqft_lot  waterfront  grade  \
# 5      1225000.0         4         5420    101930           0     11
# 21     2000000.0         3         3050     44867           0      9
# 26      937000.0         3         2450      2691           0      8
# 49     1350000.0         3         2753     65005           1      9
# 54      920000.0         5         2730      6000           0      8
# ...          ...       ...          ...       ...         ...    ...
# 21590  1222500.0         4         4910      9444           0     11
# 21593  1088000.0         5         4170      8142           0     10
# 21597  1575000.0         4         3410     10125           0     10
# 21600  1537000.0         5         4470      8088           0     11
# 21606  1007500.0         4         3510      7200           0      9
#
#        yr_built  yr_renovated     ratio  coded
# 5          2001             0  0.053174      1
# ...

# %%
df.corr(numeric_only = True)['grade']
# Out:
# price           0.667434
# bedrooms        0.356967
# sqft_living     0.762704
# sqft_lot        0.113621
# waterfront      0.082775
# grade           1.000000
# yr_built        0.446963
# yr_renovated    0.014414
# ratio           0.191771
# coded           0.014837
# Name: grade, dtype: float64

# %%
import statsmodels.api as sm
import numpy as np

X = sm.add_constant(df[['sqft_living']])
Y = df['price']
model = sm.OLS(Y, X).fit()
model.params
# Out:
# const         -43580.743094
# sqft_living      280.623568
# dtype: float64

# %%
pred = model.predict(X)
model.rsquared
# Out:
# 0.4928532179037931

# %%
df.head(5)
# Out:
#       price  bedrooms  sqft_living  sqft_lot  waterfront  grade  yr_built  \
# 0  221900.0         3         1180      5650           0      7      1955
# 1  538000.0         3         2570      7242           0      7      1951
# 2  180000.0         2          770     10000           0      6      1933
# 3  604000.0         4         1960      5000           0      7      1965
# 4  510000.0         3         1680      8080           0      8      1987
#
#    yr_renovated     ratio  coded
# 0             0  0.208850      1
# 1          1991  0.354874     20
# 2             0  0.077000      1
# 3             0  0.392000      1
# 4             0  0.207921      1

# %%
df[(df['waterfront'] == 1) & (df['sqft_lot'] > sqft_lot.mean())].var()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[277], line 1
# ----> 1 df[(df['waterfront'] == 1) & (df['sqft_lot'] > sqft_lot.mean())].var()
#
# NameError: name 'sqft_lot' is not defined
